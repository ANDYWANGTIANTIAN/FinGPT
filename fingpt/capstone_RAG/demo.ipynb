# %%
# !pip install transformers==4.37
# !pip install peft
# !pip install bitsandbytes==0.41.3
# !pip install accelerate==0.22.0 einops==0.6.1 langchain==0.0.300 xformers==0.0.21 sentence_transformers==2.2.2 chromadb==0.4.12 peft
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 76.7 MB/s eta 0:00:00:00:0100:01
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.39.3
#     Uninstalling transformers-4.39.3:
#       Successfully uninstalled transformers-4.39.3
# ...
#   Using cached accelerate-0.22.0-py3-none-any.whl.metadata (17 kB)
# ...
#   Using cached einops-0.6.1-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached langchain-0.0.300-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached xformers-0.0.21-cp310-cp310-manylinux2014_x86_64.whl.metadata (1.0 kB)
# ...
#   Using cached sentence-transformers-2.2.2.tar.gz (85 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached chromadb-0.4.12-py3-none-any.whl.metadata (7.0 kB)
# ...
#   Using cached anyio-3.7.1-py3-none-any.whl.metadata (4.7 kB)
# ...
#   Using cached langsmith-0.0.92-py3-none-any.whl.metadata (9.9 kB)
# ...

# %%
# before running this code, please change the path in the frontends.py file (line 20) to the output file
# !python /kaggle/input/rag-python-file/Embedding.py
# Out:
# The text has been stored in the file: 2nd_Apple.txt
# The text has been stored in the file: 1nd_Apple.txt
# The text has been stored in the file: 1nd_Microsoft.txt
# The text has been stored in the file: 2nd_Starbucks.txt
# .gitattributes: 100%|██████████████████████| 1.23k/1.23k [00:00<00:00, 6.99MB/s]
# 1_Pooling/config.json: 100%|███████████████████| 190/190 [00:00<00:00, 1.28MB/s]
# README.md: 100%|███████████████████████████| 10.6k/10.6k [00:00<00:00, 37.5MB/s]
# ...
# config_sentence_transformers.json: 100%|████████| 116/116 [00:00<00:00, 715kB/s]
# data_config.json: 100%|████████████████████| 39.3k/39.3k [00:00<00:00, 5.44MB/s]
# model.safetensors: 100%|██████████████████████| 438M/438M [00:01<00:00, 273MB/s]
# pytorch_model.bin: 100%|██████████████████████| 438M/438M [00:01<00:00, 276MB/s]
# sentence_bert_config.json: 100%|██████████████| 53.0/53.0 [00:00<00:00, 284kB/s]
# special_tokens_map.json: 100%|█████████████████| 239/239 [00:00<00:00, 1.21MB/s]
# ...

# %%
# change to the input folder path
# %cd /kaggle/input/rag-python-file
# Out:
# /kaggle/input/rag-python-file

# %%
# !pip install streamlit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 75.0 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 86.6 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 5.2 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# from RAG import Rag

# msg=Rag("/kaggle/working/chroma_db")
# msg.generate("please analyse the text sentiment <positive> or <negative> , the text : The stock price of Apple. Inc decreased by 5%.")
# Out:
# 2024-05-28 17:22:48.592613: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-28 17:22:48.592669: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-28 17:22:48.594133: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# config.json:   0%|          | 0.00/609 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# ...

# %%
# %cd /kaggle/working
# Out:
# /kaggle/working

# %%
# !npm install localtunnel
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# m##################] \ reify:yargs: http fetch GET 200 https://registry.npmjs.omjs.or
# added 22 packages in 1s
#
# 3 packages are looking for funding
#   run `npm fund` for details
# npm notice
# npm notice New minor version of npm available! 10.1.0 -> 10.8.0
# npm notice Changelog: https://github.com/npm/cli/releases/tag/v10.8.0
# npm notice Run npm install -g npm@10.8.0 to update!
# npm notice

# %%
# !wget -q -O - ipv4.icanhazip.com
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 35.197.116.99

# %%
# if you run in your own computer , please you this
# !streamlit run /kaggle/input/rag-python-file/frontend.py

# %%
#if you renting server and only use the jupyter, use this code, and click the link blow, the password is the result of '!wget -q -O - ipv4.icanhazip.com' (the code we run the last 2 command)
 
# !streamlit run /kaggle/input/rag-python-file/frontend.py & npx localtunnel --port 8501
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ...
#
# your url is: https://upset-kids-sink.loca.lt
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.19.2.2:8501
#   External URL: http://35.197.116.99:8501
#
# 2024-05-28 17:25:01.879358: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-28 17:25:01.879419: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...
