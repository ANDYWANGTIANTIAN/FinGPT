# %%
! pip install -U langchain openai chromadb langchain-experimental # (newest versions required for multi-modal)
! pip install "unstructured[all-docs]" pillow pydantic lxml pillow matplotlib chromadb tiktoken

# %%
# !pip install unstructured
# Out:
# Requirement already satisfied: unstructured in /opt/conda/lib/python3.10/site-packages (0.14.0)
# Requirement already satisfied: chardet in /opt/conda/lib/python3.10/site-packages (from unstructured) (5.2.0)
# Requirement already satisfied: filetype in /opt/conda/lib/python3.10/site-packages (from unstructured) (1.2.0)
# Requirement already satisfied: python-magic in /opt/conda/lib/python3.10/site-packages (from unstructured) (0.4.27)
# Requirement already satisfied: lxml in /opt/conda/lib/python3.10/site-packages (from unstructured) (5.2.1)
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (from unstructured) (3.8.1)
# Requirement already satisfied: tabulate in /opt/conda/lib/python3.10/site-packages (from unstructured) (0.9.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from unstructured) (2.31.0)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from unstructured) (4.12.3)
# Requirement already satisfied: emoji in /opt/conda/lib/python3.10/site-packages (from unstructured) (2.11.0)
# Requirement already satisfied: dataclasses-json in /opt/conda/lib/python3.10/site-packages (from unstructured) (0.6.4)
# Requirement already satisfied: python-iso639 in /opt/conda/lib/python3.10/site-packages (from unstructured) (2024.4.27)
# Requirement already satisfied: langdetect in /opt/conda/lib/python3.10/site-packages (from unstructured) (1.0.9)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from unstructured) (1.26.4)
# Requirement already satisfied: rapidfuzz in /opt/conda/lib/python3.10/site-packages (from unstructured) (3.9.0)
# Requirement already satisfied: backoff in /opt/conda/lib/python3.10/site-packages (from unstructured) (2.2.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from unstructured) (4.9.0)
# Requirement already satisfied: unstructured-client in /opt/conda/lib/python3.10/site-packages (from unstructured) (0.22.0)
# Requirement already satisfied: wrapt in /opt/conda/lib/python3.10/site-packages (from unstructured) (1.14.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->unstructured) (2.5)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/conda/lib/python3.10/site-packages (from dataclasses-json->unstructured) (3.21.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from dataclasses-json->unstructured) (0.9.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from langdetect->unstructured) (1.16.0)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from nltk->unstructured) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from nltk->unstructured) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.10/site-packages (from nltk->unstructured) (2023.12.25)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from nltk->unstructured) (4.66.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->unstructured) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->unstructured) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->unstructured) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->unstructured) (2024.2.2)
# Requirement already satisfied: deepdiff>=6.0 in /opt/conda/lib/python3.10/site-packages (from unstructured-client->unstructured) (7.0.1)
# Requirement already satisfied: jsonpath-python>=1.0.6 in /opt/conda/lib/python3.10/site-packages (from unstructured-client->unstructured) (1.0.6)
# Requirement already satisfied: mypy-extensions>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from unstructured-client->unstructured) (1.0.0)
# Requirement already satisfied: packaging>=23.1 in /opt/conda/lib/python3.10/site-packages (from unstructured-client->unstructured) (23.2)
# Requirement already satisfied: pypdf>=4.0 in /opt/conda/lib/python3.10/site-packages (from unstructured-client->unstructured) (4.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from unstructured-client->unstructured) (2.9.0.post0)
# Requirement already satisfied: ordered-set<4.2.0,>=4.1.0 in /opt/conda/lib/python3.10/site-packages (from deepdiff>=6.0->unstructured-client->unstructured) (4.1.0)

# %%
from langchain_text_splitters import CharacterTextSplitter
from unstructured.partition.pdf import partition_pdf


# Extract elements from PDF
def extract_pdf_elements(path, fname):
    """
    Extract images, tables, and chunk text from a PDF file.
    path: File path, which is used to dump images (.jpg)
    fname: File name
    """
    return partition_pdf(
        filename=path + fname,
        extract_images_in_pdf=False,
        infer_table_structure=True,
        chunking_strategy="by_title",
        max_characters=4000,
        new_after_n_chars=3800,
        combine_text_under_n_chars=2000,
        image_output_dir_path="/kaggle/working/",
    )


# Categorize elements by type
def categorize_elements(raw_pdf_elements):
    """
    Categorize extracted elements from a PDF into tables and texts.
    raw_pdf_elements: List of unstructured.documents.elements
    """
    tables = []
    texts = []
    for element in raw_pdf_elements:
        if "unstructured.documents.elements.Table" in str(type(element)):
            tables.append(str(element))
        elif "unstructured.documents.elements.CompositeElement" in str(type(element)):
            texts.append(str(element))
    return texts, tables


# File path
fpath = "/kaggle/input/report/"
fname = "1.pdf.pdf"

# Get elements
raw_pdf_elements = extract_pdf_elements(fpath, fname)

# Get text, tables
# texts, tables = categorize_elements(raw_pdf_elements)

# # Optional: Enforce a specific token size for texts
# text_splitter = CharacterTextSplitter.from_tiktoken_encoder(
#     chunk_size=4000, chunk_overlap=0
# )
# joined_texts = " ".join(texts)
# texts_4k_token = text_splitter.split_text(joined_texts)
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# Cell In[30], line 45
#      42 fname = "1.pdf.pdf"
#      44 # Get elements
# ---> 45 raw_pdf_elements = extract_pdf_elements(fpath, fname)
#      47 # Get text, tables
#      48 # texts, tables = categorize_elements(raw_pdf_elements)
#      49
#    (...)
#      54 # joined_texts = " ".join(texts)
#      55 # texts_4k_token = text_splitter.split_text(joined_texts)
#
# Cell In[30], line 12, in extract_pdf_elements(path, fname)
#       6 def extract_pdf_elements(path, fname):
#       7     """
#       8     Extract images, tables, and chunk text from a PDF file.
#       9     path: File path, which is used to dump images (.jpg)
#      10     fname: File name
#      11     """
# ---> 12     return partition_pdf(
#      13         filename=path + fname,
#      14         extract_images_in_pdf=False,
#      15         infer_table_structure=True,
#      16         chunking_strategy="by_title",
#      17         max_characters=4000,
#      18         new_after_n_chars=3800,
#      19         combine_text_under_n_chars=2000,
#      20         image_output_dir_path="/kaggle/working/",
#      21     )
#
# File /opt/conda/lib/python3.10/site-packages/unstructured/documents/elements.py:587, in process_metadata.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     585 @functools.wraps(func)
#     586 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> list[Element]:
# --> 587     elements = func(*args, **kwargs)
#     588     call_args = get_call_args_applying_defaults(func, *args, **kwargs)
#     590     regex_metadata: dict["str", "str"] = call_args.get("regex_metadata", {})
#
# File /opt/conda/lib/python3.10/site-packages/unstructured/file_utils/filetype.py:618, in add_filetype.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     616 @functools.wraps(func)
#     617 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> List[Element]:
# --> 618     elements = func(*args, **kwargs)
#     619     params = get_call_args_applying_defaults(func, *args, **kwargs)
#     620     include_metadata = params.get("include_metadata", True)
#
# File /opt/conda/lib/python3.10/site-packages/unstructured/file_utils/filetype.py:582, in add_metadata.<locals>.wrapper(*args, **kwargs)
#     580 @functools.wraps(func)
#     581 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> List[Element]:
# --> 582     elements = func(*args, **kwargs)
#     583     call_args = get_call_args_applying_defaults(func, *args, **kwargs)
#     584     include_metadata = call_args.get("include_metadata", True)
#
# File /opt/conda/lib/python3.10/site-packages/unstructured/chunking/dispatch.py:74, in add_chunking_strategy.<locals>.wrapper(*args, **kwargs)
#      71 """The decorated function is replaced with this one."""
#      73 # -- call the partitioning function to get the elements --
# ---> 74 elements = func(*args, **kwargs)
#      76 # -- look for a chunking-strategy argument --
#      77 call_args = get_call_args_applying_defaults(func, *args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/unstructured/partition/pdf.py:192, in partition_pdf(filename, file, include_page_breaks, strategy, infer_table_structure, ocr_languages, languages, include_metadata, metadata_filename, metadata_last_modified, chunking_strategy, hi_res_model_name, extract_images_in_pdf, extract_image_block_types, extract_image_block_output_dir, extract_image_block_to_payload, date_from_file_object, starting_page_number, extract_forms, form_extraction_skip_tables, **kwargs)
#     188 exactly_one(filename=filename, file=file)
#     190 languages = check_language_args(languages or [], ocr_languages) or ["eng"]
# --> 192 return partition_pdf_or_image(
#     193     filename=filename,
#     194     file=file,
#     195     include_page_breaks=include_page_breaks,
#     196     strategy=strategy,
#     197     infer_table_structure=infer_table_structure,
#     198     languages=languages,
#     199     metadata_last_modified=metadata_last_modified,
#     200     hi_res_model_name=hi_res_model_name,
#     201     extract_images_in_pdf=extract_images_in_pdf,
#     202     extract_image_block_types=extract_image_block_types,
#     203     extract_image_block_output_dir=extract_image_block_output_dir,
#     204     extract_image_block_to_payload=extract_image_block_to_payload,
#     205     date_from_file_object=date_from_file_object,
#     206     starting_page_number=starting_page_number,
#     207     extract_forms=extract_forms,
#     208     **kwargs,
#     209 )
#
# File /opt/conda/lib/python3.10/site-packages/unstructured/partition/pdf.py:287, in partition_pdf_or_image(filename, file, is_image, include_page_breaks, strategy, infer_table_structure, ocr_languages, languages, metadata_last_modified, hi_res_model_name, extract_images_in_pdf, extract_image_block_types, extract_image_block_output_dir, extract_image_block_to_payload, date_from_file_object, starting_page_number, extract_forms, form_extraction_skip_tables, **kwargs)
#     285     with warnings.catch_warnings():
#     286         warnings.simplefilter("ignore")
# --> 287         elements = _partition_pdf_or_image_local(
#     288             filename=filename,
#     289             file=spooled_to_bytes_io_if_needed(file),
#     290             is_image=is_image,
#     291             infer_table_structure=infer_table_structure,
#     292             include_page_breaks=include_page_breaks,
#     293             languages=languages,
#     294             metadata_last_modified=metadata_last_modified or last_modification_date,
#     295             hi_res_model_name=hi_res_model_name,
#     296             pdf_text_extractable=pdf_text_extractable,
#     297             extract_images_in_pdf=extract_images_in_pdf,
#     298             extract_image_block_types=extract_image_block_types,
#     299             extract_image_block_output_dir=extract_image_block_output_dir,
#     300             extract_image_block_to_payload=extract_image_block_to_payload,
#     301             starting_page_number=starting_page_number,
#     302             extract_forms=extract_forms,
#     303             form_extraction_skip_tables=form_extraction_skip_tables,
#     304             **kwargs,
#     305         )
#     306         out_elements = _process_uncategorized_text_elements(elements)
#     308 elif strategy == PartitionStrategy.FAST:
#
# File /opt/conda/lib/python3.10/site-packages/unstructured/utils.py:245, in requires_dependencies.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     236 if len(missing_deps) > 0:
#     237     raise ImportError(
#     238         f"Following dependencies are missing: {', '.join(missing_deps)}. "
#     239         + (
#    (...)
#     243         ),
#     244     )
# --> 245 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/unstructured/partition/pdf.py:536, in _partition_pdf_or_image_local(filename, file, is_image, infer_table_structure, include_page_breaks, languages, ocr_mode, model_name, hi_res_model_name, pdf_image_dpi, metadata_last_modified, pdf_text_extractable, extract_images_in_pdf, extract_image_block_types, extract_image_block_output_dir, extract_image_block_to_payload, analysis, analyzed_image_output_dir_path, starting_page_number, extract_forms, form_extraction_skip_tables, **kwargs)
#     530     logger.warning(
#     531         "The Chipper model performs better when images are rendered with DPI >= 300 "
#     532         f"(currently {pdf_image_dpi}).",
#     533     )
#     535 if file is None:
# --> 536     inferred_document_layout = process_file_with_model(
#     537         filename,
#     538         is_image=is_image,
#     539         model_name=hi_res_model_name,
#     540         pdf_image_dpi=pdf_image_dpi,
#     541     )
#     543     if hi_res_model_name.startswith("chipper"):
#     544         # NOTE(alan): We shouldn't do OCR with chipper
#     545         # NOTE(antonio): We shouldn't do PDFMiner with chipper
#     546         final_document_layout = inferred_document_layout
#
# File /opt/conda/lib/python3.10/site-packages/unstructured_inference/inference/layout.py:396, in process_file_with_model(filename, model_name, is_image, fixed_layouts, pdf_image_dpi, **kwargs)
#     386 else:
#     387     raise ValueError(f"Unsupported model type: {type(model)}")
#     388 layout = (
#     389     DocumentLayout.from_image_file(
#     390         filename,
#     391         detection_model=detection_model,
#     392         element_extraction_model=element_extraction_model,
#     393         **kwargs,
#     394     )
#     395     if is_image
# --> 396     else DocumentLayout.from_file(
#     397         filename,
#     398         detection_model=detection_model,
#     399         element_extraction_model=element_extraction_model,
#     400         fixed_layouts=fixed_layouts,
#     401         pdf_image_dpi=pdf_image_dpi,
#     402         **kwargs,
#     403     )
#     404 )
#     405 return layout
#
# File /opt/conda/lib/python3.10/site-packages/unstructured_inference/inference/layout.py:78, in DocumentLayout.from_file(cls, filename, fixed_layouts, pdf_image_dpi, **kwargs)
#      74     fixed_layouts = [None for _ in range(0, number_of_pages)]
#      75 for i, (image_path, fixed_layout) in enumerate(zip(image_paths, fixed_layouts)):
#      76     # NOTE(robinson) - In the future, maybe we detect the page number and default
#      77     # to the index if it is not detected
# ---> 78     with Image.open(image_path) as image:
#      79         page = PageLayout.from_image(
#      80             image,
#      81             number=i + 1,
#    (...)
#      84             **kwargs,
#      85         )
#      86         pages.append(page)
#
# File /opt/conda/lib/python3.10/site-packages/PIL/Image.py:3298, in open(fp, mode, formats)
#    3296     init()
#    3297 try:
# -> 3298     factory, accept = OPEN[i]
#    3299     result = not accept or accept(prefix)
#    3300     if type(result) in [str, bytes]:
#
# UnidentifiedImageError: cannot identify image file '/tmp/tmp8bs5xu_y/3f9aea6c-45a4-4c71-b439-f55d072a9aee-01.ppm'

# %%
# !apt-get install -y poppler-utils
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libpoppler97 poppler-data
# Suggested packages:
#   ghostscript fonts-japanese-mincho | fonts-ipafont-mincho
#   fonts-japanese-gothic | fonts-ipafont-gothic fonts-arphic-ukai
#   fonts-arphic-uming fonts-nanum
# The following NEW packages will be installed:
#   libpoppler97 poppler-data poppler-utils
# 0 upgraded, 3 newly installed, 0 to remove and 54 not upgraded.
# Need to get 2564 kB of archives.
# After this operation, 16.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/main amd64 poppler-data all 0.4.9-2 [1475 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libpoppler97 amd64 0.86.1-0ubuntu1.4 [916 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 poppler-utils amd64 0.86.1-0ubuntu1.4 [174 kB]
# Fetched 2564 kB in 3s (888 kB/s)
# Selecting previously unselected package poppler-data.
# (Reading database ... 110479 files and directories currently installed.)
# Preparing to unpack .../poppler-data_0.4.9-2_all.deb ...
# Unpacking poppler-data (0.4.9-2) ...
# Selecting previously unselected package libpoppler97:amd64.
# Preparing to unpack .../libpoppler97_0.86.1-0ubuntu1.4_amd64.deb ...
# Unpacking libpoppler97:amd64 (0.86.1-0ubuntu1.4) ...
# Selecting previously unselected package poppler-utils.
# Preparing to unpack .../poppler-utils_0.86.1-0ubuntu1.4_amd64.deb ...
# Unpacking poppler-utils (0.86.1-0ubuntu1.4) ...
# Setting up libpoppler97:amd64 (0.86.1-0ubuntu1.4) ...
# Setting up poppler-data (0.4.9-2) ...
# Setting up poppler-utils (0.86.1-0ubuntu1.4) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.14) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for fontconfig (2.13.1-2ubuntu3) ...

# %%
# Out:
# Name: llama-index
# Version: 0.10.37
# Summary: Interface between LLMs and your data
# Home-page: https://llamaindex.ai
# Author: Jerry Liu
# Author-email: jerry@llamaindex.ai
# License: MIT
# Location: /opt/conda/lib/python3.10/site-packages
# Requires: llama-index-agent-openai, llama-index-cli, llama-index-core, llama-index-embeddings-openai, llama-index-indices-managed-llama-cloud, llama-index-legacy, llama-index-llms-openai, llama-index-multi-modal-llms-openai, llama-index-program-openai, llama-index-question-gen-openai, llama-index-readers-file, llama-index-readers-llama-parse
# Required-by:

# %%
# Out:
# Preprocessing: 29/29
# Working: 29/29
